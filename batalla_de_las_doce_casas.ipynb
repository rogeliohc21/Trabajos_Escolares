# %%
centro=[
        "Pagina 0) has llegado al templo de Mu de ARIES ¿Que quieres hacer? \n1)Lanza un meteoro de pegaso \n2)El caballero dorado ataco primero"]




derecha=[
         "Pagina 0) has llegado al templo de Aldebaran de TAURO ¿Que quieres hacer? \n1)Lanza un meteoro de pegaso \n2)El caballero dorado ataco primero"]


izquierda=[
          "Pagina 0) has llegado al templo de Saga de GEMINIS ¿Que quieres hacer? \n1)Lanza un meteoro de pegaso \n2)El caballero dorado ataco primero"]


direc=[
         "Pagina 0) has llegado al templo de Aioria de LEO ¿Que quieres hacer? \n1)Lanza un meteoro de pegaso \n2)El caballero dorado ataco primero"]


direc2=[
         "Pagina 0) has llegado al templo de Shaka de VIRGO ¿Que quieres hacer? \n1)Lanza un meteoro de pegaso \n2)El caballero dorado ataco primero"]



derecha1=[
         "Pagina 0) has llegado al templo de Mascara de muerte de CANCER ¿Que quieres hacer? \n1)Lanza un meteoro de pegaso \n2)El caballero dorado ataco primero",

]

derecha2=[
         "Pagina 0) has llegado al templo de Milo de ESCORPIO ¿Que quieres hacer? \n1)Lanza un meteoro de pegaso \n2)El caballero dorado ataco primero",

]

derecha3=[
         "Pagina 0) has llegado al templo de Shura de CAPRICORNIO ¿Que quieres hacer? \n1)Lanza un meteoro de pegaso \n2)El caballero dorado ataco primero",

]

derecha4=[
         "Pagina 0) has llegado al templo de Camus de ACUARIO ¿Que quieres hacer? \n1)Lanza un meteoro de pegaso \n2)El caballero dorado ataco primero",
         "Pagina 1) has llegado al templo de Afrodita de PICIS ¿Que quieres hacer? \n1)Lanza un meteoro de pegaso \n2)El caballero dorado ataco primero",
]

derecha5=[
         "Pagina 0) has llegado al templo de Camus de ACUARIO ¿Que quieres hacer? \n1)Lanza un meteoro de pegaso \n2)El caballero dorado ataco primero",
]

derecha6=[
         "Pagina 0) has llegado al templo de Afrodita de PICIS ¿Que quieres hacer? \n1)Lanza un meteoro de pegaso \n2)El caballero dorado ataco primero",
]




izquierda1=[
          "Pagina 0) has llegado al templo de Doko de LIBRA ¿Que quieres hacer? \n1)Lanza un meteoro de pegaso \n2)El caballero dorado ataco primero"]



izquierda2=[
          "Pagina 0) has llegado al templo de Aioros de SAGITARIO ¿Que quieres hacer? \n1)Lanza un meteoro de pegaso \n2)El caballero dorado ataco primero"]






def mospagcentro(numpag):
  txt=centro[numpag]
  print(txt)
  from random import randint as azar
  volado = azar (1, 2)
  resp=int(input("escoge 1 o 2:  "))
  print("-"*50)
  print()
  if resp == volado:
    print("lanzo un meteoro de pegaso al caballero dorado, GANASTE pasa a la siguiente casa" )
    print("-"*50)
    print()
  else:
    print("has PERDIDO, contra el caballero dorado ")
    print("-"*50)
    print()
    mospagcentro(0)



def mospagderecha(numpag):
  txt=derecha[numpag]
  print(txt)
  from random import randint as azar
  volado = azar (1, 2)
  resp=int(input("escoge 1 o 2:  "))
  print("-"*50)
  print()
  if resp == volado:
    print("lanzo un meteoro de pegaso al caballero dorado, GANASTE pasa a la siguiente casa" )
    print("-"*50)
    print()
  else:
    print("has PERDIDO, contra el caballero dorado ")
    print("-"*50)
    print()
    mospagderecha(0)



def mospagizquierda(numpag):
  txt=izquierda[numpag]
  print(txt)
  from random import randint as azar
  volado = azar (1, 2)
  resp=int(input("escoge 1 o 2:  "))
  print("-"*50)
  print()
  if resp == volado:
    print("lanzo un meteoro de pegaso al caballero dorado, GANASTE pasa a la siguiente casa" )
    print("-"*50)
    print()
  else:
    print("has PERDIDO, contra el caballero dorado ")
    print("-"*50)
    print()
    mospagizquierda(0)


def mospagdirec(numpag):
  txt=direc[numpag]
  print(txt)
  from random import randint as azar
  volado = azar (1, 2)
  resp=int(input("escoge 1 o 2:  "))
  print("-"*50)
  print()
  if resp == volado:
    print("lanzo un meteoro de pegaso al caballero dorado, GANASTE pasa a la siguiente casa" )
    print("-"*50)
    print()
    mospagderecha2(0)
  else:
    print("has PERDIDO, contra el caballero dorado ")
    print("-"*50)
    print()
    mospagdirec(0)


def mospagdirec2(numpag):
  txt=direc2[numpag]
  print(txt)
  from random import randint as azar
  volado = azar (1, 2)
  resp=int(input("escoge 1 o 2:  "))
  print("-"*50)
  print()
  if resp == volado:
    print("lanzo un meteoro de pegaso al caballero dorado, GANASTE pasa a la siguiente casa" )
    print("-"*50)
    print()
    mospagizquierda2(0)
  else:
    print("has PERDIDO, contra el caballero dorado ")
    print("-"*50)
    print()
    mospagdirec2(0)

def mospagderecha1(numpag):
  txt=derecha1[numpag]
  print(txt)
  from random import randint as azar
  volado = azar (1, 2)
  resp=int(input("escoge 1 o 2:  "))
  print("-"*50)
  print()
  if resp == volado:
    print("lanzo un meteoro de pegaso al caballero dorado, GANASTE pasa a la siguiente casa" )
    print("-"*50)
    print()
    mospagderecha2(0)
  else:
    print("has PERDIDO, contra el caballero dorado ")
    print("-"*50)
    print()
    mospagderecha1(0)


def mospagderecha2(numpag):
  txt=derecha2[numpag]
  print(txt)
  from random import randint as azar
  volado = azar (1, 2)
  resp=int(input("escoge 1 o 2:  "))
  print("-"*50)
  print()
  if resp == volado:
    print("lanzo un meteoro de pegaso al caballero dorado, GANASTE pasa a la siguiente casa" )
    print("-"*50)
    print()
    mospagderecha3(0)
  else:
    print("has PERDIDO, contra el caballero dorado ")
    print("-"*50)
    print()
    mospagderecha2(0)

def mospagderecha3(numpag):
  txt=derecha3[numpag]
  print(txt)
  from random import randint as azar
  volado = azar (1, 2)
  resp=int(input("escoge 1 o 2:  "))
  print("-"*50)
  print()
  if resp == volado:
    print("lanzo un meteoro de pegaso al caballero dorado, GANASTE pasa a la siguiente casa" )
    print("-"*50)
    print()
    mospagderecha4(0)
  else:
    print("has PERDIDO, contra el caballero dorado ")
    print("-"*50)
    print()
    mospagderecha3(0)


def mospagderecha4(numpag):
  txt=derecha4[numpag]
  print(txt)
  from random import randint as azar
  volado = azar (1, 2)
  resp=int(input("escoge 1 o 2:  "))
  print("-"*50)
  print()
  if resp == volado:
    print("lanzo un meteoro de pegaso al caballero dorado, GANASTE pasa a la siguiente casa" )
    print("-"*50)
    print()
    mospagderecha5(0)
  else:
    print("has PERDIDO, contra el caballero dorado ")
    print("-"*50)
    print()
    mospagderecha4(0)

def mospagderecha5(numpag):
  txt=derecha5[numpag]
  print(txt)
  from random import randint as azar
  volado = azar (1, 2)
  resp=int(input("escoge 1 o 2:  "))
  print("-"*50)
  print()
  if resp == volado:
    print("lanzo un meteoro de pegaso al caballero dorado, GANASTE pasa a la siguiente casa" )
    print("-"*50)
    print()
    mospagderecha6(0)
  else:
    print("has PERDIDO, contra el caballero dorado ")
    print("-"*50)
    print()
    mospagderecha5(0)

def mospagderecha6(numpag):
  txt=derecha6[numpag]
  print(txt)
  from random import randint as azar
  volado = azar (1, 2)
  resp=int(input("escoge 1 o 2:  "))
  print("-"*50)
  print()
  if resp == volado:
    print("lanzo un meteoro de pegaso al caballero dorado, VENCISTE A TODOS LOS CABALLEROS" )
    print("-"*50)
    print()
  else:
    print("has PERDIDO, contra el caballero dorado ")
    print("-"*50)
    print()
    mospagderecha6(0)



def mospagizquierda1(numpag):
  txt=izquierda1[numpag]
  print(txt)
  from random import randint as azar
  volado = azar (1, 2)
  resp=int(input("escoge 1 o 2:  "))
  print("-"*50)
  print()
  if resp == volado:
    print("lanzo un meteoro de pegaso al caballero dorado, GANASTE pasa a la siguiente casa" )
    print("-"*50)
    print()
    mospagizquierda2(0)
  else:
    print("has PERDIDO, contra el caballero dorado ")
    print("-"*50)
    print()
    mospagizquierda1(0)


def mospagizquierda2(numpag):
  txt=izquierda2[numpag]
  print(txt)
  from random import randint as azar
  volado = azar (1, 2)
  resp=int(input("escoge 1 o 2:  "))
  print("-"*50)
  print()
  if resp == volado:
    print("lanzo un meteoro de pegaso al caballero dorado, GANASTE pasa a la siguiente casa" )
    print("-"*50)
    print()
    mospagderecha3(0)
  else:
    print("has PERDIDO, contra el caballero dorado ")
    print("-"*50)
    print()
    mospagizquierda2(0)





def elec():
  from random import randint as azar
  volado = azar (1, 2)
  print("1) aguila")
  print("2) sol")
  seiya=int(input("escoge 1 o 2:  "))
  print("-"*50)
  print()
  if seiya == volado:
    print(seiya, "avanza a la izquierda" )
    print("-"*50)
    print()
    mospagizquierda(0)
    from random import randint as azar
    volado = azar (1,2)
    print("1) aguila")
    print("2) sol")
    seiya=int(input("escoge 1 o 2:  "))
    print("-"*50)
    print()
    if seiya == volado:
      print(seiya, "avanza a la izquierda" )
      print("-"*50)
      print()
      mospagizquierda1(0)
    else:
      print(seiya, "avanza a la derecha")
      print("-"*50)
      print()
      mospagdirec2(0)

  else:
    print(seiya, "avanza a la derecha")
    print("-"*50)
    print()
    mospagderecha(0)


def elec1():
  from random import randint as azar
  volado = azar (1, 2)
  print("1) aguila")
  print("2) sol")
  seiya=int(input("escoge 1 o 2:  "))
  print("-"*50)
  print()
  if seiya == volado:
    print(seiya, "avanza a la izquierda" )
    print("-"*50)
    print()
    mospagdirec(0)
  else:
    print(seiya, "avanza a la derecha")
    print("-"*50)
    print()
    mospagderecha1(0)

def elec2():
  from random import randint as azar
  volado = azar (1, 2)
  print("1) aguila")
  print("2) sol")
  seiya=int(input("escoge 1 o 2:  "))
  print("-"*50)
  print()
  if seiya == volado:
    print(seiya, "avanza a la izquierda" )
    print("-"*50)
    print()
    mospagizquierda1(0)
  else:
    print(seiya, "avanza a la derecha")
    print("-"*50)
    print()
    mospagdirec2(0)





print("EL CABALLERO DE PEGASO TIENE UNA MISION, PARA RESCATAR A LA DIOSA SAORI QUE FUE RAPTADA")
print("EL ATAQUE PRINCIPAL DE PEGASO ES: EL METERORO DE PEGASO ESCOGE SU PODER Y VERIFICA SI PUEDES GANAR TUS COMBATES")
print("EMPIEZA TIRANDO UN VOLADO PARA SABER SI AVANZAS POR LA")
print("IZQUIERDA O DERECHA")
print("EL DESTINO DEL MUNDO ESTA EN TUS MANOS")
print("-"*50)
print()

mospagcentro(0)
print("LANZA LA MONEDA Y AVANZA AL SIGUIENTE COMBATE")
print("-"*50)
print()
elec()
print("-"*50)
print()
elec1()
print("-"*50)
print()
print("GANASTE, HAS RESCATADO A LA DIOSA ATHENA")
print("PROGRAMA DESARROLLADO POR: JOSE ROGELIO HIDALGO ")
# Out:
# EL CABALLERO DE PEGASO TIENE UNA MISION, PARA RESCATAR A LA DIOSA SAORI QUE FUE RAPTADA
# EL ATAQUE PRINCIPAL DE PEGASO ES: EL METERORO DE PEGASO ESCOGE SU PODER Y VERIFICA SI PUEDES GANAR TUS COMBATES
# EMPIEZA TIRANDO UN VOLADO PARA SABER SI AVANZAS POR LA
# IZQUIERDA O DERECHA
# EL DESTINO DEL MUNDO ESTA EN TUS MANOS
# --------------------------------------------------
#
# Pagina 0) has llegado al templo de Mu de ARIES ¿Que quieres hacer?
# 1)Lanza un meteoro de pegaso
# 2)El caballero dorado ataco primero
# escoge 1 o 2:  1
# --------------------------------------------------
#
# has PERDIDO, contra el caballero dorado
# --------------------------------------------------
#
# Pagina 0) has llegado al templo de Mu de ARIES ¿Que quieres hacer?
# 1)Lanza un meteoro de pegaso
# 2)El caballero dorado ataco primero
# escoge 1 o 2:  1
# --------------------------------------------------
#
# lanzo un meteoro de pegaso al caballero dorado, GANASTE pasa a la siguiente casa
# ...
