# %%
def calculo(a,b):
  total=a*b
  return total

print("BIENVENIDO A: ")
print("PLAYERAS RICARDO")
print("-"*25)
usuario=input("INGRESA TU USUARIO:   ")
contra=input("INGRESA TU CONTRASENA:   ")
print("-"*25)
if contra.lower() == "irc":
  print("BIENVENIDO")
  while True:
    print("ESCOGE LA TALLA DE TU PLAYERA")
    print("1) chica ")
    print("2) mediana ")
    print("3) grande ")
    print("4) SALIR")
    playera=input("INICIA TU PEDIDO: ")
    if playera == "1":
      print("chica")
      while True:
        print("ESCOGE EL COLOR")
        print("1) ROJA $20 ")
        print("2) AZUL $30 ")
        print("3) VERDE $40 ")
        print("4) SALIR")
        color=input("COLOR: ")
        if color == "1":
          print("playera chica de color rojo $ 20")
          a=int(input("INGRESA LA CANTIDAD DE PLAYERAS A COMPRAR:  "))
          b=int(input("INGRESA EL COSTO:   "))
          tot_fin=calculo(a,b)
          print(f"EL TOTAL ES: {tot_fin}")
          break
        elif color == "2":
          print("playera chica de color azul $ 30")
          a=int(input("INGRESA LA CANTIDAD DE PLAYERAS:  "))
          b=int(input("INGRESA EL COSTO:   "))
          tot_fin=calculo(a,b)
          print(f"EL TOTAL ES: {tot_fin}")
          break
        elif color == "3":
          print("playera chica de color verde $ 40")
          a=int(input("INGRESA LA CANTIDAD DE PLAYERAS:  "))
          b=int(input("INGRESA EL COSTO:   "))
          tot_fin=calculo(a,b)
          print(f"EL TOTAL ES: {tot_fin}")
          break
        elif color == "4":
          print("ADIOS")
          break
        else:
          print("ERROR")
      break
    elif playera == "2":
      print("mediana")
      while True:
        print("ESCOGE EL COLOR")
        print("1) ROJA $20 ")
        print("2) AZUL $30 ")
        print("3) VERDE $40 ")
        print("4) SALIR")
        color=input("COLOR: ")
        if color == "1":
          print("playera mediana de color rojo $ 20")
          a=int(input("INGRESA LA CANTIDAD DE PLAYERAS:  "))
          b=int(input("INGRESA EL COSTO:   "))
          tot_fin=calculo(a,b)
          print(f"EL TOTAL ES: {tot_fin}")
          break
        elif color == "2":
          print("playera mediana de color azul $ 30")
          a=int(input("INGRESA LA CANTIDAD DE PLAYERAS:  "))
          b=int(input("INGRESA EL COSTO:   "))
          tot_fin=calculo(a,b)
          print(f"EL TOTAL ES: {tot_fin}")
          break
        elif color == "3":
          print("playera mediana de color verde $ 40")
          a=int(input("INGRESA LA CANTIDAD DE PLAYERAS:  "))
          b=int(input("INGRESA EL COSTO:   "))
          tot_fin=calculo(a,b)
          print(f"EL TOTAL ES: {tot_fin}")
          break
        elif color == "4":
          print("ADIOS")
          break
        else:
          print("ERROR")
      break
    elif playera == "3":
      print("grande")
      while True:
        print("ESCOGE EL COLOR")
        print("1) ROJA $20 ")
        print("2) AZUL $30 ")
        print("3) VERDE $40 ")
        print("4) SALIR")
        color=input("COLOR: ")
        if color == "1":
          print("playera grande de color rojo $ 20")
          a=int(input("INGRESA LA CANTIDAD DE PLAYERAS:  "))
          b=int(input("INGRESA EL COSTO:   "))
          tot_fin=calculo(a,b)
          print(f"EL TOTAL ES: {tot_fin}")
          break
        elif color == "2":
          print("playera grande de color azul $ 30")
          a=int(input("INGRESA LA CANTIDAD DE PLAYERAS:  "))
          b=int(input("INGRESA EL COSTO:   "))
          tot_fin=calculo(a,b)
          print(f"EL TOTAL ES: {tot_fin}")
          break
        elif color == "3":
          print("playera grande de color verde $ 40")
          a=int(input("INGRESA LA CANTIDAD DE PLAYERAS:  "))
          b=int(input("INGRESA EL COSTO:   "))
          tot_fin=calculo(a,b)
          print(f"EL TOTAL ES: {tot_fin}")
          break
        elif color == "4":
          print("ADIOS")
          break
        else:
          print("ERROR")
      break
    elif playera == "4":
      print("ADIOS")
      break
    else:
      print("ERROR")


else:
  print("CONTRASEÑA INCORRECTA")
# Out:
# BIENVENIDO A:
# PLAYERAS RICARDO
# -------------------------
# INGRESA TU USUARIO:   rogelio
# INGRESA TU CONTRASENA:   irc
# -------------------------
# BIENVENIDO
# ESCOGE LA TALLA DE TU PLAYERA
# 1) chica
# 2) mediana
# 3) grande
# 4) SALIR
# INICIA TU PEDIDO: 1
# chica
# ESCOGE EL COLOR
# 1) ROJA $20
# 2) AZUL $30
# 3) VERDE $40
# 4) SALIR
# COLOR: 2
# playera chica de color azul $ 30
# INGRESA LA CANTIDAD DE PLAYERAS:  4
# INGRESA EL COSTO:   30
# EL TOTAL ES: 120
