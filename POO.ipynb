# %%
def examen(relacion):
  for i in relacion:
    print(i)

pregunta_1 = []
respuesta_1 = []
pregunta_2 = []
respuesta_2 = []
pregunta_3 = []
respuesta_3 = []
pregunta_4 = []
respuesta_4 = []
pregunta_5 = []
respuesta_5 = []
comentarios = []

pregunta_1 = ["1.¿Cúal es uno de los principios de la POO, que se dedica a agrupar datos y procedimientos en unidades logicas?"]
respuesta_1 = ["1) Encapsulación", "2) Abstracción", "3) Herencia", "4) Polimorfismo"]
pregunta_2 = ["2.¿Cúal es uno de los principios POO, que se encarga de ocultar los detalles de la implementación?"]
respuesta_2 = ["1) Herencia", "2) Encapsulación", "3) Abstracción", "4) Polimorfismo"]
pregunta_3 = ["3.¿se le conoce como proceso de modelado, donde se identifican lo problemas y su comportamiento?"]
respuesta_3 = ["1) Abstracción", "2) Herencia", "3) Resolucion de problematicas", "4) programacion orientada a objetos"]
pregunta_4 = ["4.¿Cúal es la principal funcion que tiene la POO en los programadores ?"]
respuesta_4 = ["1) esquematizar", "2) disminuir trabajo", "3) reutilizacion de codigo y un codigo mas organizado", "4) mejor forma de programar"]
pregunta_5 = ["5.¿Qué principio permite trabajar en equipo minimizando la duplicacion de funciones?"]
respuesta_5 = ["1) Herencia", "2) Abstracción", "3) Encapsulación", "4) Poliformismo"]
comentarios = [""]



alumno = input("Ingresa tu nombre. ")
print( alumno, ", Bienvenido ")
grupo = input("Ingresa tu licenciatura y grupo. ")
print()

print("Muy bien,", alumno, "del grupo: ", grupo, ". comienza tu examen sobre; Programacion orientada a objetos.")
print("-"*50)
print("Nombre:   ",  alumno)
print("Grupo:    ",  grupo)
print()
print("-"*50)
print("1) Inicia el examen")
print("2) Salir")
opc=int(input("INGRESA LA OPCION REQUERIDA:  "))
while True:
  if opc == 1:
    print(" leé con mucha atencion y responde ")
    print("")
    print("-"*50)
    total = 0
    while True:
      examen(pregunta_1)
      examen(respuesta_1)
      respuesta=input("la respuesta correcta es:   ")
      if respuesta == "1":
        total=total+2
        break
      elif respuesta == "2":
        total=total+0
        break
      elif respuesta == "3":
        total=total+0
        break
      elif respuesta == "4":
        total=total+0
        break
      else:
        print("ERROR opcion NO valida")
    print()
    print("-"*50)
    total = 0
    while True:
      examen(pregunta_2)
      examen(respuesta_2)
      respuesta=input("la respuesta correcta es:   ")
      if respuesta == "1":
        total=total+0
        break
      elif respuesta == "2":
        total=total+0
        break
      elif respuesta == "3":
        total=total+2
        break
      elif respuesta == "4":
        total=total+0
        break
      else:
        print("ERROR opcion NO valida")
    print()
    print("-"*50)
    total = 0
    while True:
      examen(pregunta_3)
      examen(respuesta_3)
      respuesta=input("la respuesta correcta es:   ")
      if respuesta == "1":
        total=total+0
        break
      elif respuesta == "2":
        total=total+0
        break
      elif respuesta == "3":
        total=total+0
        break
      elif respuesta == "4":
        total=total+2
        break
      else:
        print("ERROR opcion NO valida")
    print()
    print("-"*50)
    total = 0
    while True:
      examen(pregunta_4)
      examen(respuesta_4)
      respuesta=input("la respuesta correcta es:   ")
      if respuesta == "1":
        total=total+0
        break
      elif respuesta == "2":
        total=total+0
        break
      elif respuesta == "3":
        total=total+2
        break
      elif respuesta == "4":
        total=total+0
        break
      else:
        print("ERROR opcion NO valida")
    print()
    print("-"*50)
    total = 0
    while True:
      examen(pregunta_5)
      examen(respuesta_5)
      respuesta=input("la respuesta correcta es:   ")
      if respuesta == "1":
        total=total+0
        break
      elif respuesta == "2":
        total=total+0
        break
      elif respuesta == "3":
        total=total+2
        break
      elif respuesta == "4":
        total=total+0
        break
      else:
        print("ERROR opcion NO valida")
    print()
    print("-"*50)
    while True:
      print("3) Deja algun comentario sobre el examen ")
      print("4) Salir ")
      opc=int(input("Escoge una opcion: "))
      if opc ==3:
        print("")
        coment=input("ingresa tu comentario:  ")
        comentarios.append(coment)
        examen(comentarios)
        break
      elif opc ==4:
        print("ADIOS")
        break
      else:
        print("ERROR ingresa nuevamnete la opcion requerida ")
  print("Programa desarrollado por:  JOSE ROGELIO HIDALGO CIRIGO")
  print("")
  print("-"*50)
  if opc == 2:
    print("ADIOS")
    break
  else:
    break
  print("")
  print("-"*50)
while True:
  print("")
  print("-"*50)
  print("3) intenta de nuevo el examen ")
  print("4) Deja algun comentario sobre el examen ")
  print("5) Salir ")
  opc=int(input("Escoge una opcion: "))
  if opc == 3:
    print(" leé con mucha atencion y responde ")
    print("")
    print("-"*50)
    total1=0
    while True:
      examen(pregunta_1)
      examen(respuesta_1)
      respuesta=input("la respuesta correcta es:   ")
      if respuesta == "1":
        total1=total+2
        break
      elif respuesta == "2":
        total1=total+0
        break
      elif respuesta == "3":
        total1=total+0
        break
      elif respuesta == "4":
        total1=total+0
        break
      else:
        print("ERROR opcion NO valida")
    print()
    print("-"*50)
    total2=0
    while True:
      examen(pregunta_2)
      examen(respuesta_2)
      respuesta=input("la respuesta correcta es:   ")
      if respuesta == "1":
        total2=total+0
        break
      elif respuesta == "2":
        total2=total+0
        break
      elif respuesta == "3":
        total2=total+2
        break
      elif respuesta == "4":
        total2=total+0
        break
      else:
        print("ERROR opcion NO valida")
    print()
    print("-"*50)
    total3=0
    while True:
      examen(pregunta_3)
      examen(respuesta_3)
      respuesta=input("la respuesta correcta es:   ")
      if respuesta == "1":
        total3=total+0
        break
      elif respuesta == "2":
        total3=total+0
        break
      elif respuesta == "3":
        total3=total+0
        break
      elif respuesta == "4":
        total3=total+2
        break
      else:
        print("ERROR opcion NO valida")
    print()
    print("-"*50)
    total4=0
    while True:
      examen(pregunta_4)
      examen(respuesta_4)
      respuesta=input("la respuesta correcta es:   ")
      if respuesta == "1":
        total4=total+0
        break
      elif respuesta == "2":
        total4=total+0
        break
      elif respuesta == "3":
        total4=total+2
        break
      elif respuesta == "4":
        total4=total+0
        break
      else:
        print("ERROR opcion NO valida")
    print()
    print("-"*50)
    total5=0
    while True:
      examen(pregunta_5)
      examen(respuesta_5)
      respuesta=input("la respuesta correcta es:   ")
      if respuesta == "1":
        total5=total+0
        break
      elif respuesta == "2":
        total5=total+0
        break
      elif respuesta == "3":
        total5=total+2
        break
      elif respuesta == "4":
        total5=total+0
        break
      else:
        print("ERROR opcion NO valida")
    print()
    print("-"*50)
    gt=total1+total2+total3+total4+total5
    print("tu calificacion es:  ", gt)
    if gt>=8 and gt <=10:
      print("APROBASTE")
      print("FELICIDADES DOMINAS EL TEMA")

    elif gt>=6 and gt<=18:
      print("APROBASTE")
      print("SIGUE REPASANDO EL TEMA")

    elif gt>=0 and gt<=5:
      print("REPROBASTE")
      print("ESTUDIA MAS")

    else:
      print("error")
      print("Programa desarrollado por:  Ricardo Arroyo Hernández")
  elif opc == 4:
    print("")
    coment=input("ingresa tu comentario:  ")
    comentarios.append(coment)
    examen(comentarios)
    break
  elif opc == 5:
    print("ADIOS")
    break
  else:
    print("ERROR ingresa nuevamnete la opcion requerida ")
print("Programa desarrollado por:  JOSE ROGELIO HIDALGO CIRIGO")
# Out:
# Ingresa tu nombre. Ricardo
# Ricardo , Bienvenido
# Ingresa tu licenciatura y grupo. LCDA 102
#
# Muy bien, Ricardo del grupo:  LCDA 102 . comienza tu examen sobre; Programacion orientada a objetos.
# --------------------------------------------------
# Nombre:    Ricardo
# Grupo:     LCDA 102
#
# --------------------------------------------------
# 1) Inicia el examen
# 2) Salir
# INGRESA LA OPCION REQUERIDA:  1
#  leé con mucha atencion y responde
#
# --------------------------------------------------
# 1.¿Cúal es uno de los principios de la POO, que se dedica a agrupar datos y procedimientos en unidades logicas?
# 1) Encapsulación
# 2) Abstracción
# 3) Herencia
# 4) Polimorfismo
# la respuesta correcta es:   2
#
# --------------------------------------------------
# 2.¿Cúal es uno de los principios POO, que se encarga de ocultar los detalles de la implementación?
# 1) Herencia
# 2) Encapsulación
# 3) Abstracción
# 4) Polimorfismo
# la respuesta correcta es:   3
#
# ...
